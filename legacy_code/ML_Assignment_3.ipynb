# %%
import pandas as pd

# %%
dataset = pd.read_csv('as3dataset.csv')

# %%
dataset.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research    Ad
# 0         1  0.92
# 1         1  0.76
# 2         1  0.72
# 3         1  0.80
# 4         0  0.65

# %%
#Adding a new Column Admitted

# %%
dataset.insert(9,"Admitted",dataset["Ad"]>=0.87)

# %%
dataset.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research    Ad  Admitted
# 0         1  0.92      True
# 1         1  0.76     False
# 2         1  0.72     False
# 3         1  0.80     False
# 4         0  0.65     False

# %%
#dropping Unrequired Columns

# %%
dataset1= dataset.drop(columns=['Serial No.','Ad'])

# %%
dataset1.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Admitted
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False

# %% [markdown]
# # Preprocessing

# %%
#checking for NULL Values

# %%
dataset1.isna().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Admitted             0
# dtype: int64

# %%
#changing categorical data to numerical Data

# %%
dataset1['Admitted'].replace([True,False],[1,0],inplace=True)

# %%
dataset1.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Admitted
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# # **Plotting**

# %% [markdown]
# scatter Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset1.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Admitted
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0

# %%
sns.scatterplot(x="SOP",y="University Rating",data=dataset1)
# Out:
# <Axes: xlabel='SOP', ylabel='University Rating'>

# %%
sns.scatterplot(x="SOP",y="University Rating",data=dataset1,hue="CGPA")
# Out:
# <Axes: xlabel='SOP', ylabel='University Rating'>

# %% [markdown]
#  BAR GRAPH

# %%
sns.barplot(data=dataset,x="SOP",y="University Rating")
# Out:
# <Axes: xlabel='SOP', ylabel='University Rating'>

# %% [markdown]
# Distributed Plot

# %%
sns.displot(x="SOP",data=dataset1)

# %% [markdown]
# ### **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
x = dataset1.drop('Admitted',axis=1)

# %%
x.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0

# %%
y = dataset1[['Admitted']]

# %%
y.head()
# Out:
#    Admitted
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0

# %%
train_x,test_x,train_y,test_y = train_test_split(x,y)

# %%
train_y.head()
# Out:
#      Admitted
# 177         0
# 133         0
# 288         0
# 363         0
# 245         0

# %% [markdown]
# # **Decision Tree Classification**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model2 = DecisionTreeClassifier(criterion="gini")

# %%
model2.predict(train_x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-e43f7cae5aa8> in <cell line: 1>()
# ----> 1 model2.predict(train_x)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     425         check_is_fitted(self)
#     426         X = self._validate_X_predict(X, check_input)
# --> 427         proba = self.tree_.predict(X)
#     428         n_samples = X.shape[0]
#     429
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'tree_'
