# %%
! /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 7.0 MB/s eta 0:00:00a 0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip

# %% [markdown]
# ### Pandas Library

# %%
import pandas as pd

# %% [markdown]
# ## Key Data structures in Pandas
#
# * Series
# * Dataframe

# %%
s = pd.Series([1,2,3,4,5])

# Series is a labelled array

# %%
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
 # Data frame 
df = pd.DataFrame({"name":["Abhishek","Rohan","Aryan"],"Marks":[12,23,43]})
df
# Out:
#        name  Marks
# 0  Abhishek     12
# 1     Rohan     23
# 2     Aryan     43

# %%
# Reading a csv dataset
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#   STRUCTURE      STRUCTURE_ID     STRUCTURE_NAME ACTION LOCATION  Country  \
# 0  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      AUT  Austria
# 1  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      BEL  Belgium
# 2  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CAN   Canada
# 3  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CZE  Czechia
# 4  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      DNK  Denmark
#
#   INDICATOR                 Indicator MEASURE Measure  ... OBS_VALUE  \
# 0   JE_LMIS  Labour market insecurity       L   Value  ...       2.3
# 1   JE_LMIS  Labour market insecurity       L   Value  ...       2.4
# 2   JE_LMIS  Labour market insecurity       L   Value  ...       3.8
# 3   JE_LMIS  Labour market insecurity       L   Value  ...       2.3
# 4   JE_LMIS  Labour market insecurity       L   Value  ...       4.5
#
#   Observation Value  OBS_STATUS  Observation Status UNIT_MEASURE  \
# ...

# %%
df.shape
# Out:
# (2369, 22)

# %%
df.describe()
# Out:
#            OBS_VALUE  Observation Value  Observation Status  UNIT_MULT  \
# count    2369.000000                0.0                 0.0     2369.0
# mean     5299.220612                NaN                 NaN        0.0
# std     41894.336828                NaN                 NaN        0.0
# min         0.000000                NaN                 NaN        0.0
# 25%         7.100000                NaN                 NaN        0.0
# 50%        66.000000                NaN                 NaN        0.0
# 75%        88.000000                NaN                 NaN        0.0
# max    941162.000000                NaN                 NaN        0.0
#
#        BASE_PER  Base reference period
# count       0.0                    0.0
# mean        NaN                    NaN
# std         NaN                    NaN
# min         NaN                    NaN
# 25%         NaN                    NaN
# 50%         NaN                    NaN
# 75%         NaN                    NaN
# ...
