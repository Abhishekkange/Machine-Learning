# %%
import numpy as np

# %%
weights = np.random.randn(2)

# %%
weights
# Out:
# array([ 1.12841188, -0.72494392])

# %%
input_vector = np.array([[2,0],[1,2],[3,2],[5,0]])
output_vector = [0,1,1,0]

# %%
input_vector.shape
# Out:
# (4, 2)

# %%
summation_formula = np.dot(input_vector,weights)

# %%
summation_formula
# Out:
# array([ 2.25682376, -0.32147597,  1.93534779,  5.6420594 ])

# %%
test_arr = np.array([1,2,-2,0,-3])
result = test_arr>=0

# %%
result.astype(int)
# Out:
# array([1, 1, 0, 1, 0])

# %%
error = np.array([0.1,-0.1,0.2,-0.2])
print(error.shape)
learning_rate = 0.1
# Out:
# (4,)

# %%
print(input_vector)
# Out:
# [[2 0]
#  [1 2]
#  [3 2]
#  [5 0]]

# %%
print(input_vector.shape)
# Out:
# (4, 2)

# %%
abc = np.dot(input_vector.T,error)
abc
# Out:
# array([-0.3,  0.2])

# %%
weights = weights+ learning_rate * abc

# %%
weights
# Out:
# array([ 1.14241188, -0.73294392])
