# %% [markdown]
# ### DBSCAN - Density based spatial Clustering of Application with Noise

# %%
# creating a dummy moons dataset

from sklearn.datasets import make_moons

# %%
x,y = make_moons(n_samples = 1000,noise=0.05)

# %%
import matplotlib.pyplot as plt

#scatter plot 
plt.figure(figsize=(15, 10)) 
plt.scatter(x[:, 0], x[:, 1])
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Scatter Plot of Blobs Dataset")
plt.show()

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.05,min_samples=5)
dbscan.fit(x)
# Out:
# DBSCAN(eps=0.05)

# %%
dbscan.labels_

# all -1 are considered anomalies by this algoritm
# Out:
# array([ 0,  0,  0,  5,  0,  1,  0,  1,  2,  3,  4,  7,  0,  3,  1,  4,  2,
#         0,  0,  5,  0,  6,  7,  0,  1,  3,  1,  4,  5,  0,  3,  1,  7,  2,
#         1, 11,  0,  1,  4,  0, -1,  0,  8,  1,  2,  1,  5,  6,  0,  6,  0,
#         0,  0,  2, -1, -1,  1,  0, -1,  3, -1,  2,  0,  6,  9,  1, -1,  5,
#         0,  1, 10,  0,  0, 10,  0,  2,  2,  0,  1,  0,  0,  0,  0,  1,  1,
#         3,  1,  5,  4,  1,  3,  6, 11, -1,  9, -1,  0,  1,  1,  7,  0, 10,
#         0, 10,  5,  1,  1,  2,  1, -1,  0,  2,  6,  0,  4,  3,  1,  4,  9,
#         4,  6,  6,  1,  0,  0,  4,  4,  6,  8,  0,  0,  4,  6, 10,  7,  6,
#         8,  0,  1,  1,  0,  6,  1,  1, -1,  0,  0,  0,  5,  1,  2,  1, -1,
#         4,  1, 10,  1, 11,  1,  0,  2,  3,  6,  0,  1,  8,  5,  0,  4,  2,
#         8,  1,  1, 11,  3, -1,  7,  1,  1,  2,  2,  3,  1,  3,  0,  0, -1,
#        -1,  0,  0,  8,  6,  2,  0,  4,  1,  7,  2,  6,  2,  6,  2,  0,  4,
#         0,  1,  4,  2,  0, -1,  0,  1, -1,  1,  0,  3,  1,  2,  2,  2,  6,
#         6,  4, -1,  2, -1, 10,  0,  1,  2, 11,  6,  6,  0,  1,  1, -1,  1,
#        11,  1,  0,  0,  1,  0,  2,  2,  2,  6,  0, 11,  6, 11,  1,  1,  5,
#         1,  7,  0,  1,  1,  1,  2,  1,  1,  0,  1, 10,  7,  1,  6,  0,  1,
#         1,  1,  0, 10, -1,  6,  1,  5,  6,  4,  0, 10, -1,  1,  2, 10,  3,
#         0,  0,  0,  1,  5, 11,  6,  0, 11, -1,  0,  2,  1, -1,  1,  4,  6,
#         6, -1,  1,  1,  4,  0, 11,  0,  0,  3,  3,  1, 10,  1,  2,  0,  1,
#         3,  1,  1,  1, -1,  0,  1,  1,  5,  5,  0,  1,  0,  5,  1, -1, -1,
#        -1,  5,  1,  2,  1,  0,  4,  1,  4,  5,  4,  3,  0,  0,  7, -1,  5,
#        10,  0,  0,  2,  3,  6,  0,  1,  1,  0,  2,  0,  0,  1,  2,  1,  6,
#         0,  0,  0,  0,  1,  1, 11,  2, 11,  0,  4,  4,  4,  3,  2,  1,  1,
#         0,  2,  6, -1,  4,  1,  1,  1,  1,  2,  4,  0,  6, 10,  1,  0, 11,
#        -1,  2,  1, -1, -1,  0,  1, 11,  2,  1,  3, 11,  1,  4,  1,  1,  0,
#         0,  5,  0,  1,  2,  5,  0,  0,  1,  1,  5, -1,  0,  4,  2,  0, 10,
#         4,  2,  6,  4,  0,  5, 11,  1,  1,  1,  0,  0,  0,  0,  2,  0,  2,
#         1,  6,  1,  0,  4,  0, -1,  0,  3,  2,  1, 11,  1,  5, -1,  5,  0,
#         2,  1,  3,  3,  2, -1,  4,  2, 10,  1,  2,  0,  1,  0,  5,  2,  6,
#         1,  1,  5,  2,  0,  1,  0,  7,  1,  3,  2,  4,  5,  4,  7,  3,  0,
#         1,  0,  8, 10,  0,  3,  6,  0,  3,  0, -1,  4, -1,  5,  0,  6,  1,
#         1,  0,  1,  4, -1,  7,  1,  1,  4,  1,  1, -1,  1, -1, -1,  0,  4,
#         0, -1,  0,  8,  0,  0,  0,  1, -1,  1,  8,  6,  4,  2,  4,  1,  1,
#         0,  5,  8,  0,  0,  4,  0,  2, -1,  5,  0, -1,  2,  1,  1,  5,  1,
#         7, -1,  2,  3,  0, 10,  1,  2,  1,  0,  4, 11,  3,  6,  1,  2, 10,
#         1,  2, 10,  1,  3,  6, 10,  0,  6,  2,  0,  1,  2,  1,  6,  3,  7,
#         0,  1,  2,  2,  1,  3,  2,  1,  6,  0,  0,  6,  6,  0,  0,  1,  2,
#         0,  1,  0, 10,  3,  1,  1, -1, -1,  1,  1,  0, 10,  3,  0,  3,  1,
#        -1,  1,  2,  0,  4,  0,  2,  0, 10,  1,  1,  1,  4,  1,  3,  2,  2,
#         0, -1,  1,  4,  2,  5,  2,  1,  2, 11,  1,  3,  1,  5,  0,  0,  3,
#         1, 11, -1,  2,  1,  1,  0,  0,  1,  4,  1,  6,  0,  1,  4,  3,  2,
#         0,  2,  4,  1,  2,  4,  0, 11,  6,  2, 10,  0,  0,  0, 10,  4,  0,
#        10,  6,  1, 11,  1,  5,  2, 10, -1,  3, -1,  1,  0,  1,  4,  1,  0,
#         1,  0,  2,  0,  1,  0,  0,  6,  4,  0,  1,  2,  2, -1,  1,  0, 10,
#         1, -1,  2,  4,  1,  2,  0,  7,  1,  2,  0,  4,  1,  4,  0,  5,  1,
#         1,  2,  6,  1,  3, -1,  4, 11,  2,  1,  6,  2,  0,  4,  1, 10,  2,
#         5,  5,  1,  1,  1,  0,  0,  0,  0,  6, 10,  1,  1,  1,  2,  1,  1,
#        -1,  3, 10,  1,  3,  0,  7,  1,  6,  1,  1,  2,  1,  0,  4,  4,  7,
#         0,  1,  0, 11,  3,  6,  1,  0,  1,  3,  0,  6,  7,  3,  5,  2, 11,
#        -1,  4,  7,  0,  1,  0,  6,  1,  6,  9,  0,  7,  7,  1, 10,  5,  3,
#         2,  0,  3,  1,  1,  1,  0,  6,  1,  0,  0,  0, 11,  1,  1,  1,  4,
#         3,  1, 11,  1,  7, 11, 10,  1,  3,  3,  3, 11,  1,  4,  3, -1,  1,
#         1,  1,  0,  7,  0,  2,  6, 10,  6,  7,  2,  0,  5,  4,  5,  1,  1,
#         0,  6,  1,  0,  6,  2, -1, -1,  1,  7,  0,  5,  0,  0,  8,  1,  5,
#        11,  4,  7,  4,  0,  1,  0,  4,  0,  4,  6,  1, 11,  1,  1, 10, -1,
#         5,  6,  7,  1,  3,  0,  2,  0,  3,  2, -1,  2,  5,  0,  7,  4, -1,
#         0,  5,  4,  7,  2,  7,  7,  0,  1,  1, 10,  1,  1,  8,  0,  0,  7,
#         1,  1,  0, -1,  4,  0,  6,  0,  1,  0,  1,  1, 11,  1,  3, -1,  0,
#         1,  1,  1,  4,  0,  5,  0,  2,  5,  4,  9,  1,  2,  0])

# %% [markdown]
# ### Using KNN Classifier to predict labels for unsupervised data

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=50)
knn.fit(dbscan.components_, dbscan.labels_[dbscan.core_sample_indices_])
# Out:
# KNeighborsClassifier(n_neighbors=50)
