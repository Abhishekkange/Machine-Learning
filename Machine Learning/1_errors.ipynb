# %% [markdown]
# ### RMSE (Root Mean Square Error)

# %%
import numpy as np

# %%
#calculating RMSE
actual_value = np.array([10,34,12,43,45,34])
predicted_value = np.array([10,34,11,43,44,34])

rmse = np.sqrt(np.mean((predicted_value-actual_value)**2))
print("Root Mean Square Error is :",rmse)
# Out:
# Root Mean Square Error is : 0.5773502691896257
