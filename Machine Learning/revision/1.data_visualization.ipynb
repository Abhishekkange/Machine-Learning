# %% [markdown]
# ## Understanding the Data

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/abhishek/Machine-Learning/datasets/housing/housing.csv")
df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df["longitude"].dtype
# Out:
# dtype('float64')

# %%
df["longitude"].isnull().count()
# Out:
# np.int64(20640)

# %%
df["longitude"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df["ocean_proximity"].unique()
df["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
# Out:
# longitude
# -124.35              NEAR OCEAN
# -124.30    NEAR OCEANNEAR OCEAN
# -124.27              NEAR OCEAN
# -124.26              NEAR OCEAN
# -124.25              NEAR OCEAN
#                    ...
# -114.56                  INLAND
# -114.55                  INLAND
# -114.49                  INLAND
# -114.47                  INLAND
# -114.31                  INLAND
# Name: ocean_proximity, Length: 844, dtype: object

# %%
df["median_house_value"].hist()
# Out:
# <Axes: >

# %%
df["median_house_value"].hist(bins=50)
# Out:
# <Axes: >

# %%
(df["median_house_value"]==500000).sum()
# Out:
# np.int64(27)

# %%
import matplotlib.pyplot as plt

plt.scatter(x=df["longitude"],y=df["latitude"],c=df["median_house_value"],alpha=0.3)

# %%
plt.scatter(x=df["median_income"],y=df["median_house_value"])

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df, test_size=0.2)

# %%
train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16551    -121.23     37.82                14.0       1847.0           325.0
# 15428    -117.24     33.21                19.0       1872.0           489.0
# 16349    -121.36     38.03                14.0       2356.0           438.0
# 14450    -117.24     32.81                34.0       2420.0           391.0
# 18777    -122.24     40.45                27.0       1804.0           321.0
# ...          ...       ...                 ...          ...             ...
# 10121    -117.93     33.93                37.0       1128.0           273.0
# 15379    -117.25     33.36                 6.0       3725.0           960.0
# 17837    -121.90     37.44                12.0       4228.0           734.0
# 4380     -118.27     34.09                52.0       2327.0           555.0
# 16060    -122.49     37.76                49.0       1724.0           295.0
#
# ...
