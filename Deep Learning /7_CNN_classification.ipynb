# %% [markdown]
# ### Classification using CNN

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets,layers,models
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train,Y_train),(X_test,Y_test) = datasets.cifar10.load_data()

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
plt.imshow(X_train[30])

# %%
X_train = X_train/255
X_test = X_test/255

# %%
Y_train = Y_train.reshape(-1,)

# %%
Y_train[0]
# Out:
# np.uint8(6)

# %%
classes = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

# %%
cnn = keras.Sequential([

    #cnn
    layers.Conv2D(filters=30,activation='relu',kernel_size=(3,3),input_shape=(32,32,3)),
    layers.MaxPool2D((2,2)),

    layers.Conv2D(filters=64,activation='relu',kernel_size=(3,3)),
    layers.MaxPool2D((2,2)),



    #deep network
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(10,activation='softmax')
])

# %%
cnn.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
cnn.fit(X_train,Y_train,epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.2814 - loss: 2.0007
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.3327 - loss: 1.8603
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.3699 - loss: 1.7541
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.3912 - loss: 1.6885
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.4033 - loss: 1.6505
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.4181 - loss: 1.6182
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.4316 - loss: 1.5832
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.4410 - loss: 1.5578
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.4447 - loss: 1.5405
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.4551 - loss: 1.5224

# %%
X_test = X_test
Y_test = Y_test.reshape(-1,)

# %%
Y_test[0]
X_test= X_test/255

# %%
cnn.evaluate(X_test,Y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4551 - loss: 1.5238
# [1.5237990617752075, 0.45509999990463257]
