# %% [markdown]
# ### Activation Functions

# %% [markdown]
# ### Sigmoid Function

# %%
import math

def sigmoid(x):
    return 1/(1+math.exp(x))

# %%
sigmoid(1)
# Out:
# 0.2689414213699951

# %%
sigmoid(-20)
# Out:
# 0.9999999979388463

# %%
sigmoid(10)
# Out:
# 4.5397868702434395e-05

# %% [markdown]
# ### Tanh Function
