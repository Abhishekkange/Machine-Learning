# %% [markdown]
# ### Hand Digit Classification using CNN

# %%
# import dataset 
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
# X_train = x.iloc[:60000]
# f = X_train
# X_test = x.iloc[60000:]
# Y_train = y.iloc[:60000].astype(int)
# Y_test = y.iloc[60000:].astype(int)

# %%
#scaling the features
X_train = X_train/255

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential([


    #cnn
    keras.layers.Conv2D(filters=30,activation='relu',input_shape=(28,28,1),kernel_size=(2,2)),
    keras.layers.MaxPool2D((2,2)),

    keras.layers.Conv2D(filters=64,activation='relu',kernel_size=(2,2)),
    keras.layers.MaxPool2D((2,2)),

    #dense
    keras.layers.Flatten(),
    keras.layers.Dense(10,activation='sigmoid')
])



model.compile(
    optimizer = 'adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']

    )
# Out:
# /opt/homebrew/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7064 - loss: 0.9612
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8790 - loss: 0.3973
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9014 - loss: 0.3302
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9151 - loss: 0.2850
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9260 - loss: 0.2485

# %%
X_test = X_test/255

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9365 - loss: 0.2146
# [0.21461617946624756, 0.9365000128746033]
